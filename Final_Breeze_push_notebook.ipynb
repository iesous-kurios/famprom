# %% [markdown]
# <a href="https://colab.research.google.com/github/iesous-kurios/famprom/blob/master/Final_Breeze_push_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
giving = pd.read_excel('/content/fpspokane-giving-01-05-2021 (1).xlsx')

# %%
people = pd.read_excel('/content/fpspokane-people-01-05-2021.xlsx')

# %%
giving.head()
# Out:
#          Date  Batch  ...  Card                                               Note
# 0  2021-01-04    229  ...   NaN                                                NaN
# 1  2021-01-03    229  ...   NaN                                                NaN
# 2  2021-01-03    229  ...   NaN  Night Without a Bed Pledge -- one full year fo...
# 3  2021-01-02    228  ...   NaN                                                NaN
# 4  2021-01-02    228  ...   NaN                                                NaN
#
# [5 rows x 13 columns]

# %%
giving = giving.rename(columns = {'Person ID': 'Breeze ID'})

# %%
giving.head()
# Out:
#          Date  Batch  ...  Card                                               Note
# 0  2021-01-04    229  ...   NaN                                                NaN
# 1  2021-01-03    229  ...   NaN                                                NaN
# 2  2021-01-03    229  ...   NaN  Night Without a Bed Pledge -- one full year fo...
# 3  2021-01-02    228  ...   NaN                                                NaN
# 4  2021-01-02    228  ...   NaN                                                NaN
#
# [5 rows x 13 columns]

# %%
people.head()
# Out:
#    Breeze ID First Name  ... Causes or Passion  Added Date
# 0   21464546        Pam  ...               NaN  01/23/2020
# 1   21463258       Emma  ...               NaN  01/23/2020
# 2   21463354       Geng  ...               NaN  01/23/2020
# 3   21463704       John  ...               NaN  01/23/2020
# 4   21464136      Lydia  ...               NaN  01/23/2020
#
# [5 rows x 73 columns]

# %%
people_giving = giving.merge(people, on = 'Breeze ID')

# %%
people.shape
# Out:
# (6405, 73)

# %%
giving.shape
# Out:
# (7757, 13)

# %%
people_giving.shape
# Out:
# (7754, 85)

# %%
people_giving.head()
# Out:
#          Date  Batch  ...  Causes or Passion  Added Date
# 0  2021-01-04    229  ...                NaN  08/17/2020
# 1  2020-12-04    224  ...                NaN  08/17/2020
# 2  2020-11-04    219  ...                NaN  08/17/2020
# 3  2020-10-04    213  ...                NaN  08/17/2020
# 4  2020-09-04    202  ...                NaN  08/17/2020
#
# [5 rows x 85 columns]

# %%
people_giving.to_excel('/content/people_giving.xlsx')
